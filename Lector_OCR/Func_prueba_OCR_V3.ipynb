# %% [markdown]
# # Lector de Reconocedor de caractéres

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# @title instalar módulos con la información relacionada
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install tesseract-ocr-spa
# !pip install pdf2image

# Instalar la librería PyOcr
# !pip install pyocr

# Instalar la librería Wand
# !apt-get install wand
# !apt install wand
! apt-get install libmagickwand-dev
! pip install Wand

# Instalar la librería Pillow
# !pip install pillow
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-spa is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libmagickwand-dev is already the newest version (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.
# ...

# %% [markdown]
# ## Version 1

# %%
# @title Importamos las librerías
from wand.image import Image
from PIL import Image as PI
import pyocr
import pyocr.builders
import io
import sys

# %%
tool = pyocr.get_available_tools()[0]
lang = 'spa'

def show_config():
    tools = pyocr.get_available_tools()
    if len(tools) == 0:
        print("Herramienta OCR o encontrada.")
        sys.exit(1)
    # print("* Herramientas OCR disponibles en %s:", tool.get_module())
    for tool in tools:
        print('  - %s' % tool)
        langs = tool.get_available_languages()
        print("    - Lenguajes disponibles: %s" % ", ".join(langs))

show_config()
# Out:
#   - <module 'pyocr.tesseract' from '/usr/local/lib/python3.10/dist-packages/pyocr/tesseract.py'>
#     - Lenguajes disponibles: eng, osd, spa
#   - <module 'pyocr.libtesseract' from '/usr/local/lib/python3.10/dist-packages/pyocr/libtesseract/__init__.py'>
#     - Lenguajes disponibles: eng, osd, spa

# %%
### Cargamos el fichero PDF y convertimos cada una de sus páginas en una imagen JPEG (objeto blob)
image_pdf = Image(filename="/content/jpegfile.pdf", resolution=300)
image_jpeg = image_pdf.convert('jpeg')
# Out:
# ---------------------------------------------------------------------------
# PolicyError                               Traceback (most recent call last)
# <ipython-input-33-3f476b10592e> in <cell line: 2>()
#       1 ### Cargamos el fichero PDF y convertimos cada una de sus páginas en una imagen JPEG (objeto blob)
# ----> 2 image_pdf = Image(filename="/content/jpegfile.pdf", resolution=300)
#       3 image_jpeg = image_pdf.convert('jpeg')
#
# /usr/local/lib/python3.10/dist-packages/wand/image.py in __init__(self, image, blob, file, filename, pseudo, background, colorspace, depth, extract, format, height, interlace, resolution, sampling_factors, units, width)
#    9363                     self.read(blob=blob)
#    9364                 elif filename is not None:
# -> 9365                     self.read(filename=filename)
#    9366                 # clear the wand format, otherwise any subsequent call to
# ...

# %%
### Guardamos todas las imágenes en un array
page_jpeg_list = []
for img in image_jpeg.sequence:
    img_page = Image(image=img)
    page_jpeg_list.append(img_page.make_blob('jpeg'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-7bcd83d19da0> in <cell line: 3>()
#       1 ### Guardamos todas las imágenes en un array
#       2 page_jpeg_list = []
# ----> 3 for img in image_jpeg.sequence:
#       4     img_page = Image(image=img)
#       5     page_jpeg_list.append(img_page.make_blob('jpeg'))
#
# NameError: name 'image_jpeg' is not defined

# %%
#! /usr/bin/env python3
# -*- coding: utf-8 -*-

### Importamos las librerías
from wand.image import Image as WImg
from PIL import Image as PI
import pyocr
import pyocr.builders
import os
import io
import sys


from wand.image import Image
from PIL import Image as PI
import pyocr
import pyocr.builders
import io
import sys

def show_config():
    tools = pyocr.get_available_tools()
    if len(tools) == 0:
        print("Herramienta OCR o encontrada.")
        sys.exit(1)
    print("* Herramientas OCR disponibles:")
    for tool in tools:
        print('  - %s' % tool)
        langs = tool.get_available_languages()
        print("    - Lenguajes disponibles en %s: %s" % (tool.get_name(), ", ".join(langs)))

#show_config()

tool = pyocr.get_available_tools()[0]
lang = 'spa'

### Cargamos el fichero PDF y convertimos cada una de sus páginas en una imagen JPEG (objeto blob)
image_pdf = Image(filename="/content/jpegfile.pdf", resolution=300)
image_jpeg = image_pdf.convert('jpeg')

### Guardamos todas las imágenes en un array
page_jpeg_list = []
for img in image_jpeg.sequence:
    img_page = Image(image=img)
    page_jpeg_list.append(img_page.make_blob('jpeg'))

### Recorremos el array de imágenes y extraemos el texto de cada una de ellas aplicando OCR
page_text_list = []
for img in page_jpeg_list:
    text = tool.image_to_string(PI.open(io.BytesIO(img)), lang=lang, builder=pyocr.builders.TextBuilder())
    page_text_list.append(text)
    print('- Página %2s: %5s caracteres' % (len(page_text_list), len(text)))

### Guardamos el texto en un fichero:
fp = open('textfile.txt', 'w')
fp.write('\n\n'.join(page_text_list))
fp.close()
# Out:
# ---------------------------------------------------------------------------
# PolicyError                               Traceback (most recent call last)
# <ipython-input-36-c7ede9ce64ba> in <cell line: 38>()
#      36
#      37 ### Cargamos el fichero PDF y convertimos cada una de sus páginas en una imagen JPEG (objeto blob)
# ---> 38 image_pdf = Image(filename="/content/jpegfile.pdf", resolution=300)
#      39 image_jpeg = image_pdf.convert('jpeg')
#      40
#
# /usr/local/lib/python3.10/dist-packages/wand/image.py in __init__(self, image, blob, file, filename, pseudo, background, colorspace, depth, extract, format, height, interlace, resolution, sampling_factors, units, width)
#    9363                     self.read(blob=blob)
#    9364                 elif filename is not None:
# -> 9365                     self.read(filename=filename)
#    9366                 # clear the wand format, otherwise any subsequent call to
# ...

# %% [markdown]
# ## Version 2

# %%
# !pip install pytesseract

# %%
# !ls
# Out:
# jpegfile.pdf  sample_data

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.2 [186 kB]
# Fetched 186 kB in 1s (303 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 124079 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.2_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.2) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.2) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
from pdf2image import convert_from_path


# Almacenar el pdf con la función convert_from_path
pages = convert_from_path('jpegfile.pdf')

for i in range(len(pages)):
   # Guardar página como imagen
   pages[i].save('page'+ str(i) +'_2.jpg', 'JPEG')

# %%
import cv2
import pytesseract

img = cv2.imread('page0.jpg')

# Adding custom options
custom_config = r'--oem 3 --psm 6'
print(pytesseract.image_to_string(img, config=custom_config))
# Out:
# Procesamiento del Lenguaje Natural, boletin n° 12, Julio de 1992 43
# Adquisicién de conocimiento léxico: Acquilex.
# A. Ageno (1) I. Castell6n (1) M.A. Martf (2) F. Ribas (1) G. Rigau (1)
# H. Rodriguez (1) M. Taulé (2) F Verdejo (3)
# (1) Universitat Politécnica de Catalunya. Departament de LSI. Barcelona.
# (2) Universitat de Barcelona. Departament de Filologia RomAnica. Barcelona
# (3) UNED Departamento de Ingenieria Electrica, Electrénica y de Control. Madrid
# 1. Introduccién.
# El objetivo bdsico del proyecto ACQUILEX es el desarrollo de técnicas y métodos que
# permitan la utilizacidn de diccionarios en soporte magnético (M.R.D, Machine Readable
# Dictionaries) en la construccién de componentes Iéxicas para sistemas de procesamiento del
# lenguaje natural (P.L.N).
# Los diccionarios automatizados constituyen una fuente de adquisicié6n de Conocimiento
# Léxico y conceptual que, potencialmente, permite abordar algunos aspectos especialmente
# ...

# %%
# Almacenar el pdf con la función convert_from_path
pages = convert_from_path('prueba/ReportePDA_SamuelMúneraVillarreal_data.pdf')

for i in range(len(pages)):
   # Guardar página como imagen
   pages[i].save('page'+ str(i) +'_2.jpg', 'JPEG')

# %%
import cv2
import pytesseract

img = cv2.imread('page0_2.jpg')

# Adding custom options
custom_config = r'--oem 3 --psm 6'
print(pytesseract.image_to_string(img, config=custom_config))
# Out:
# | Reporte de Perfil Conductual de
# POA & Samuel Munera Villarreal
# Grafico Perfil Conductual
# NATURAL ADAPTADO
# .
# c co
# = =
# & &
# > e
# oe oe
# a a
# |
# R EP NA R E P NA
# # 5 9 8 4 4 # 6 8 8 2 5
# 1E 43% 63% 45% 51% 18% IE 49% 60% 47% 45% 28%
# Toma de Decisiones Toma de Decisiones
# Pe SSSI
# 20% 68%
# Intensidad del Perfil Intensidad del Perfil
# ean =. mm | =
# 30% 26%
# Energia Energia
# eam = = |} =
# 43% 41%
# Equilibrio de Energia
# | 1} =e
# 46%
# Modificaci6n del Perfil
# =i | —-
# 72%
# Tiempo del Formulario
# a LD
# 11 min
# ©2004 PDA International 15

# %%
# importante

# %%
# Almacenar el pdf con la función convert_from_path
pages = convert_from_path('prueba/ReportePDA_SamuelMúneraVillarreal.pdf')

for i in range(len(pages)):
   # Guardar página como imagen
   pages[i].save('page'+ str(i) +'_3.jpg', 'JPEG')

# %%
import cv2
import pytesseract

img = cv2.imread('page0_3.jpg')

# Adding custom options
custom_config = r'--oem 3 --psm 6'
print(pytesseract.image_to_string(img, config=custom_config))
# Out:
# | Reporte de Perfil Conductual de
# POA Cop Samuel Munera Villarreal
# Grafico Perfil Conductual
# NATURAL ADAPTADO
# .
# c c
# = =
# & s
# 2 2
# » & o
# a a
# R E P NA R E P NA
# = 5 9 8 4 4 # 6 8 8 2 5
# IE 43% 63% 45% 51% 18% IE 49% 60% 47% 45% 28%
# Toma de Decisiones Toma de Decisiones
# Fe z= a
# 20% 68%
# Intensidad del Perfil Intensidad del Perfil
# am = mm | =
# 30% 26%
# Energia Energia
# SS =p =a |} =)
# 43% 41%
# Equilibrio de Energia
# =i 1} —
# 46%
# Modificaci6n del Perfil
# =i =
# 72%
# Tiempo del Formulario
# ea Li:
# 11 min
# ©2004 PDA International 15
