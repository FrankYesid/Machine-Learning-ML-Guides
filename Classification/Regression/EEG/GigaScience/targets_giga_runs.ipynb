# %%
# !pip install mne==0.19
# !pip install -U git+https://github.com/UN-GCPDS/python-gcpds.utils.git
from gcpds.utils import loaddb
# Out:
# Requirement already satisfied: mne==0.19 in /usr/local/lib/python3.6/dist-packages (0.19.0)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from mne==0.19) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from mne==0.19) (1.19.5)
# Collecting git+https://github.com/UN-GCPDS/python-gcpds.utils.git
#   Cloning https://github.com/UN-GCPDS/python-gcpds.utils.git to /tmp/pip-req-build-foxuzswt
#   Running command git clone -q https://github.com/UN-GCPDS/python-gcpds.utils.git /tmp/pip-req-build-foxuzswt
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from gcpds-utils==0.1a3) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from gcpds-utils==0.1a3) (1.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib in /usr/local/lib/python3.6/dist-packages (from gcpds-utils==0.1a3) (3.2.2)
# Requirement already satisfied, skipping upgrade: mne in /usr/local/lib/python3.6/dist-packages (from gcpds-utils==0.1a3) (0.19.0)
# Requirement already satisfied, skipping upgrade: tables in /usr/local/lib/python3.6/dist-packages (from gcpds-utils==0.1a3) (3.4.4)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from gcpds-utils==0.1a3) (4.41.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->gcpds-utils==0.1a3) (1.3.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->gcpds-utils==0.1a3) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->gcpds-utils==0.1a3) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->gcpds-utils==0.1a3) (2.4.7)
# Requirement already satisfied, skipping upgrade: numexpr>=2.5.2 in /usr/local/lib/python3.6/dist-packages (from tables->gcpds-utils==0.1a3) (2.7.2)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from tables->gcpds-utils==0.1a3) (1.15.0)
# Building wheels for collected packages: gcpds-utils
#   Building wheel for gcpds-utils (setup.py) ... done
#   Created wheel for gcpds-utils: filename=gcpds_utils-0.1a3-cp36-none-any.whl size=96836 sha256=ed647279a7f2ce21370756556b59f213617465bafd21dbb3a7cb6acbef8e5a51
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gzhssgq6/wheels/ab/4a/1e/d215a31a12c0fa202a9bccc9b9d68874deb08dfdce8b7d43c8
# Successfully built gcpds-utils
# Installing collected packages: gcpds-utils
#   Found existing installation: gcpds-utils 0.1a3
#     Uninstalling gcpds-utils-0.1a3:
#       Successfully uninstalled gcpds-utils-0.1a3
# Successfully installed gcpds-utils-0.1a3

# %%
FILEID = "1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O CKA_keras.py && rm -rf /tmp/cookies.txt
# !dir
# Out:
# --2021-01-19 14:37:26--  https://docs.google.com/uc?export=download&confirm=&id=1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK
# Resolving docs.google.com (docs.google.com)... 108.177.98.113, 108.177.98.101, 108.177.98.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.98.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-0c-docs.googleusercontent.com/docs/securesc/9vmibo8smte52hn4pqgqmtn56530474s/a5bric7v92svefueetm63a6kbj8hs0at/1611066975000/06932581800131476027/04138025236380975614Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e=download [following]
# --2021-01-19 14:37:26--  https://doc-0c-0c-docs.googleusercontent.com/docs/securesc/9vmibo8smte52hn4pqgqmtn56530474s/a5bric7v92svefueetm63a6kbj8hs0at/1611066975000/06932581800131476027/04138025236380975614Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e=download
# Resolving doc-0c-0c-docs.googleusercontent.com (doc-0c-0c-docs.googleusercontent.com)... 173.194.203.132, 2607:f8b0:400e:c05::84
# Connecting to doc-0c-0c-docs.googleusercontent.com (doc-0c-0c-docs.googleusercontent.com)|173.194.203.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=tb6nsjcjmaoee&continue=https://doc-0c-0c-docs.googleusercontent.com/docs/securesc/9vmibo8smte52hn4pqgqmtn56530474s/a5bric7v92svefueetm63a6kbj8hs0at/1611066975000/06932581800131476027/04138025236380975614Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e%3Ddownload&hash=c2fp1f314bap122inbhb34b0bs4mumqq [following]
# --2021-01-19 14:37:27--  https://docs.google.com/nonceSigner?nonce=tb6nsjcjmaoee&continue=https://doc-0c-0c-docs.googleusercontent.com/docs/securesc/9vmibo8smte52hn4pqgqmtn56530474s/a5bric7v92svefueetm63a6kbj8hs0at/1611066975000/06932581800131476027/04138025236380975614Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e%3Ddownload&hash=c2fp1f314bap122inbhb34b0bs4mumqq
# Connecting to docs.google.com (docs.google.com)|108.177.98.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0c-0c-docs.googleusercontent.com/docs/securesc/9vmibo8smte52hn4pqgqmtn56530474s/a5bric7v92svefueetm63a6kbj8hs0at/1611066975000/06932581800131476027/04138025236380975614Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e=download&nonce=tb6nsjcjmaoee&user=04138025236380975614Z&hash=cd9q2lumjg7urho98dopn584ucnedh49 [following]
# --2021-01-19 14:37:27--  https://doc-0c-0c-docs.googleusercontent.com/docs/securesc/9vmibo8smte52hn4pqgqmtn56530474s/a5bric7v92svefueetm63a6kbj8hs0at/1611066975000/06932581800131476027/04138025236380975614Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e=download&nonce=tb6nsjcjmaoee&user=04138025236380975614Z&hash=cd9q2lumjg7urho98dopn584ucnedh49
# Connecting to doc-0c-0c-docs.googleusercontent.com (doc-0c-0c-docs.googleusercontent.com)|173.194.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6933 (6.8K) [text/plain]
# Saving to: ‘CKA_keras.py’
#
# CKA_keras.py        100%[===================>]   6.77K  --.-KB/s    in 0s
#
# 2021-01-19 14:37:27 (78.9 MB/s) - ‘CKA_keras.py’ saved [6933/6933]
#
# CKA_keras.py		  drive			    MIfunctions.py  sample_data
# databases		  __MACOSX		    __pycache__
# Data_resting_C3andC4.mat  Means_giga_mayo.mat	    R0
# Data_rest_r0.zip	  means_ponderado_giga.mat  Resting

# %%
#%% download data
FILEID = "1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O MIfunctions.py && rm -rf /tmp/cookies.txt
#%% download data
# Out:
# --2021-01-19 14:37:29--  https://docs.google.com/uc?export=download&confirm=&id=1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG
# Resolving docs.google.com (docs.google.com)... 74.125.195.113, 74.125.195.102, 74.125.195.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.195.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-8s-docs.googleusercontent.com/docs/securesc/u4164h609g56uri3ugt1ppusku2irqtl/mqd76es3qv74bbsn34pt6gqgb65msp6m/1611066975000/06932581800131476027/01635602484887467284Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e=download [following]
# --2021-01-19 14:37:29--  https://doc-0c-8s-docs.googleusercontent.com/docs/securesc/u4164h609g56uri3ugt1ppusku2irqtl/mqd76es3qv74bbsn34pt6gqgb65msp6m/1611066975000/06932581800131476027/01635602484887467284Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e=download
# Resolving doc-0c-8s-docs.googleusercontent.com (doc-0c-8s-docs.googleusercontent.com)... 173.194.203.132, 2607:f8b0:400e:c05::84
# Connecting to doc-0c-8s-docs.googleusercontent.com (doc-0c-8s-docs.googleusercontent.com)|173.194.203.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=7sltepavqc2bc&continue=https://doc-0c-8s-docs.googleusercontent.com/docs/securesc/u4164h609g56uri3ugt1ppusku2irqtl/mqd76es3qv74bbsn34pt6gqgb65msp6m/1611066975000/06932581800131476027/01635602484887467284Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e%3Ddownload&hash=5nomhr7qf8fubtradthr7emm7k3nh4gr [following]
# --2021-01-19 14:37:30--  https://docs.google.com/nonceSigner?nonce=7sltepavqc2bc&continue=https://doc-0c-8s-docs.googleusercontent.com/docs/securesc/u4164h609g56uri3ugt1ppusku2irqtl/mqd76es3qv74bbsn34pt6gqgb65msp6m/1611066975000/06932581800131476027/01635602484887467284Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e%3Ddownload&hash=5nomhr7qf8fubtradthr7emm7k3nh4gr
# Connecting to docs.google.com (docs.google.com)|74.125.195.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0c-8s-docs.googleusercontent.com/docs/securesc/u4164h609g56uri3ugt1ppusku2irqtl/mqd76es3qv74bbsn34pt6gqgb65msp6m/1611066975000/06932581800131476027/01635602484887467284Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e=download&nonce=7sltepavqc2bc&user=01635602484887467284Z&hash=6huvdh2vl6iu31hups1vuj3uhp2k3fo1 [following]
# --2021-01-19 14:37:30--  https://doc-0c-8s-docs.googleusercontent.com/docs/securesc/u4164h609g56uri3ugt1ppusku2irqtl/mqd76es3qv74bbsn34pt6gqgb65msp6m/1611066975000/06932581800131476027/01635602484887467284Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e=download&nonce=7sltepavqc2bc&user=01635602484887467284Z&hash=6huvdh2vl6iu31hups1vuj3uhp2k3fo1
# Connecting to doc-0c-8s-docs.googleusercontent.com (doc-0c-8s-docs.googleusercontent.com)|173.194.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45989 (45K) [text/x-python]
# Saving to: ‘MIfunctions.py’
#
# MIfunctions.py      100%[===================>]  44.91K  --.-KB/s    in 0s
#
# 2021-01-19 14:37:30 (94.5 MB/s) - ‘MIfunctions.py’ saved [45989/45989]

# %%
from gcpds.utils import loaddb
import sys
from scipy.io import loadmat,savemat
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import numpy as np
from joblib import dump, load
from sklearn.svm import LinearSVC, SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split,GridSearchCV, StratifiedShuffleSplit
from mne.viz import plot_topomap
#from keras_cka_v3 import Keras_CKA # import keras_cka function wrapped for sklearn.
from CKA_keras import Keras_CKA # import keras_cka function wrapped for sklearn.
from MIfunctions import * #importar todas las funciones de manejo de eeg con mne.
import os
import time
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, cohen_kappa_score, pairwise_distances
from sklearn.metrics import make_scorer
import pickle

# %%
FILEID = "1tIAIAymOYi3gK7HtPoGi0Y6X6lpo-H_3"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O Data_rest_r0.zip && rm -rf /tmp/cookies.txt
# !dir
# !unzip Data_rest_r0.zip
# Out:
# --2021-01-19 14:37:39--  https://docs.google.com/uc?export=download&confirm=l7Y7&id=1tIAIAymOYi3gK7HtPoGi0Y6X6lpo-H_3
# Resolving docs.google.com (docs.google.com)... 74.125.142.102, 74.125.142.113, 74.125.142.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-40-docs.googleusercontent.com/docs/securesc/rl5l2huk7aa2ne3admlafesmt7nqeb14/r6ir3isr862dqmnphd4qsrur56ebf5db/1611067050000/13064322042220169363/08639204306415908193Z/1tIAIAymOYi3gK7HtPoGi0Y6X6lpo-H_3?e=download [following]
# --2021-01-19 14:37:39--  https://doc-0g-40-docs.googleusercontent.com/docs/securesc/rl5l2huk7aa2ne3admlafesmt7nqeb14/r6ir3isr862dqmnphd4qsrur56ebf5db/1611067050000/13064322042220169363/08639204306415908193Z/1tIAIAymOYi3gK7HtPoGi0Y6X6lpo-H_3?e=download
# Resolving doc-0g-40-docs.googleusercontent.com (doc-0g-40-docs.googleusercontent.com)... 173.194.203.132, 2607:f8b0:400e:c05::84
# Connecting to doc-0g-40-docs.googleusercontent.com (doc-0g-40-docs.googleusercontent.com)|173.194.203.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=f3a44378ltlhu&continue=https://doc-0g-40-docs.googleusercontent.com/docs/securesc/rl5l2huk7aa2ne3admlafesmt7nqeb14/r6ir3isr862dqmnphd4qsrur56ebf5db/1611067050000/13064322042220169363/08639204306415908193Z/1tIAIAymOYi3gK7HtPoGi0Y6X6lpo-H_3?e%3Ddownload&hash=542rcm9g2g9urff39ld27ubmjktuj8tt [following]
# --2021-01-19 14:37:40--  https://docs.google.com/nonceSigner?nonce=f3a44378ltlhu&continue=https://doc-0g-40-docs.googleusercontent.com/docs/securesc/rl5l2huk7aa2ne3admlafesmt7nqeb14/r6ir3isr862dqmnphd4qsrur56ebf5db/1611067050000/13064322042220169363/08639204306415908193Z/1tIAIAymOYi3gK7HtPoGi0Y6X6lpo-H_3?e%3Ddownload&hash=542rcm9g2g9urff39ld27ubmjktuj8tt
# Connecting to docs.google.com (docs.google.com)|74.125.142.102|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0g-40-docs.googleusercontent.com/docs/securesc/rl5l2huk7aa2ne3admlafesmt7nqeb14/r6ir3isr862dqmnphd4qsrur56ebf5db/1611067050000/13064322042220169363/08639204306415908193Z/1tIAIAymOYi3gK7HtPoGi0Y6X6lpo-H_3?e=download&nonce=f3a44378ltlhu&user=08639204306415908193Z&hash=i7smptfnn595ik1gc7jfafm85u1gg471 [following]
# --2021-01-19 14:37:40--  https://doc-0g-40-docs.googleusercontent.com/docs/securesc/rl5l2huk7aa2ne3admlafesmt7nqeb14/r6ir3isr862dqmnphd4qsrur56ebf5db/1611067050000/13064322042220169363/08639204306415908193Z/1tIAIAymOYi3gK7HtPoGi0Y6X6lpo-H_3?e=download&nonce=f3a44378ltlhu&user=08639204306415908193Z&hash=i7smptfnn595ik1gc7jfafm85u1gg471
# Connecting to doc-0g-40-docs.googleusercontent.com (doc-0g-40-docs.googleusercontent.com)|173.194.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘Data_rest_r0.zip’
#
# Data_rest_r0.zip        [           <=>      ] 569.50M   107MB/s    in 5.7s
#
# 2021-01-19 14:37:46 (100 MB/s) - ‘Data_rest_r0.zip’ saved [597163754]
#
# CKA_keras.py		  drive			    MIfunctions.py  sample_data
# databases		  __MACOSX		    __pycache__
# Data_resting_C3andC4.mat  Means_giga_mayo.mat	    R0
# Data_rest_r0.zip	  means_ponderado_giga.mat  Resting
# Archive:  Data_rest_r0.zip
# replace Data_resting_C3andC4.mat? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: Data_resting_C3andC4.mat
#   inflating: __MACOSX/._Data_resting_C3andC4.mat
#   inflating: Means_giga_mayo.mat
#   inflating: __MACOSX/._Means_giga_mayo.mat
#   inflating: means_ponderado_giga.mat
#   inflating: __MACOSX/._means_ponderado_giga.mat
#   inflating: R0/LpR0_s37.mat
#   inflating: __MACOSX/R0/._LpR0_s37.mat
#   inflating: R0/LpR0_s23.mat
#   inflating: __MACOSX/R0/._LpR0_s23.mat
#   inflating: R0/LpR0_s22.mat
#   inflating: __MACOSX/R0/._LpR0_s22.mat
#   inflating: R0/LpR0_s36.mat
#   inflating: __MACOSX/R0/._LpR0_s36.mat
#   inflating: R0/LpR0_s20.mat
#   inflating: __MACOSX/R0/._LpR0_s20.mat
#   inflating: R0/LpR0_s35.mat
#   inflating: __MACOSX/R0/._LpR0_s35.mat
#   inflating: R0/LpR0_s21.mat
#   inflating: __MACOSX/R0/._LpR0_s21.mat
#   inflating: R0/LpR0_s25.mat
#   inflating: __MACOSX/R0/._LpR0_s25.mat
#   inflating: R0/LpR0_s31.mat
#   inflating: __MACOSX/R0/._LpR0_s31.mat
#   inflating: R0/LpR0_s19.mat
#   inflating: __MACOSX/R0/._LpR0_s19.mat
#   inflating: R0/LpR0_s18.mat
#   inflating: __MACOSX/R0/._LpR0_s18.mat
#   inflating: R0/LpR0_s30.mat
#   inflating: __MACOSX/R0/._LpR0_s30.mat
#   inflating: R0/LpR0_s24.mat
#   inflating: __MACOSX/R0/._LpR0_s24.mat
#   inflating: R0/LpR0_s32.mat
#   inflating: __MACOSX/R0/._LpR0_s32.mat
#   inflating: R0/LpR0_s26.mat
#   inflating: __MACOSX/R0/._LpR0_s26.mat
#   inflating: R0/LpR0_s27.mat
#   inflating: __MACOSX/R0/._LpR0_s27.mat
#   inflating: R0/LpR0_s33.mat
#   inflating: __MACOSX/R0/._LpR0_s33.mat
#   inflating: R0/LpR0_s6.mat
#   inflating: __MACOSX/R0/._LpR0_s6.mat
#   inflating: R0/LpR0_s40.mat
#   inflating: __MACOSX/R0/._LpR0_s40.mat
#   inflating: R0/LpR0_s41.mat
#   inflating: __MACOSX/R0/._LpR0_s41.mat
#   inflating: R0/LpR0_s7.mat
#   inflating: __MACOSX/R0/._LpR0_s7.mat
#   inflating: R0/LpR0_s5.mat
#   inflating: __MACOSX/R0/._LpR0_s5.mat
#   inflating: R0/LpR0_s43.mat
#   inflating: __MACOSX/R0/._LpR0_s43.mat
#   inflating: R0/LpR0_s42.mat
#   inflating: __MACOSX/R0/._LpR0_s42.mat
#   inflating: R0/LpR0_s4.mat
#   inflating: __MACOSX/R0/._LpR0_s4.mat
#   inflating: R0/LpR0_s46.mat
#   inflating: __MACOSX/R0/._LpR0_s46.mat
#   inflating: R0/LpR0_s52.mat
#   inflating: __MACOSX/R0/._LpR0_s52.mat
#   inflating: R0/LpR0_s47.mat
#   inflating: __MACOSX/R0/._LpR0_s47.mat
#   inflating: R0/LpR0_s1.mat
#   inflating: __MACOSX/R0/._LpR0_s1.mat
#   inflating: R0/LpR0_s3.mat
#   inflating: __MACOSX/R0/._LpR0_s3.mat
#   inflating: R0/LpR0_s51.mat
#   inflating: __MACOSX/R0/._LpR0_s51.mat
#   inflating: R0/LpR0_s45.mat
#   inflating: __MACOSX/R0/._LpR0_s45.mat
#   inflating: R0/LpR0_s44.mat
#   inflating: __MACOSX/R0/._LpR0_s44.mat
#   inflating: R0/LpR0_s50.mat
#   inflating: __MACOSX/R0/._LpR0_s50.mat
#   inflating: R0/LpR0_s2.mat
#   inflating: __MACOSX/R0/._LpR0_s2.mat
#   inflating: R0/LpR0_s49.mat
#   inflating: __MACOSX/R0/._LpR0_s49.mat
#   inflating: R0/LpR0_s48.mat
#   inflating: __MACOSX/R0/._LpR0_s48.mat
#   inflating: R0/LpR0_s9.mat
#   inflating: __MACOSX/R0/._LpR0_s9.mat
#   inflating: R0/LpR0_s8.mat
#   inflating: __MACOSX/R0/._LpR0_s8.mat
#   inflating: R0/LpR0_s16.mat
#   inflating: __MACOSX/R0/._LpR0_s16.mat
#   inflating: R0/LpR0_s17.mat
#   inflating: __MACOSX/R0/._LpR0_s17.mat
#   inflating: R0/LpR0_s15.mat
#   inflating: __MACOSX/R0/._LpR0_s15.mat
#   inflating: R0/LpR0_s14.mat
#   inflating: __MACOSX/R0/._LpR0_s14.mat
#   inflating: R0/LpR0_s28.mat
#   inflating: __MACOSX/R0/._LpR0_s28.mat
#   inflating: R0/LpR0_s10.mat
#   inflating: __MACOSX/R0/._LpR0_s10.mat
#   inflating: R0/LpR0_s38.mat
#   inflating: __MACOSX/R0/._LpR0_s38.mat
#   inflating: R0/LpR0_s39.mat
#   inflating: __MACOSX/R0/._LpR0_s39.mat
#   inflating: R0/LpR0_s11.mat
#   inflating: __MACOSX/R0/._LpR0_s11.mat
#   inflating: R0/LpR0_s13.mat
#   inflating: __MACOSX/R0/._LpR0_s13.mat
#   inflating: R0/LpR0_s12.mat
#   inflating: __MACOSX/R0/._LpR0_s12.mat
#   inflating: Resting/s32_r.mat
#   inflating: __MACOSX/Resting/._s32_r.mat
#   inflating: Resting/s6_r.mat
#   inflating: __MACOSX/Resting/._s6_r.mat
#   inflating: Resting/s16_r.mat
#   inflating: __MACOSX/Resting/._s16_r.mat
#   inflating: Resting/s51_r.mat
#   inflating: __MACOSX/Resting/._s51_r.mat
#   inflating: Resting/s14_r.mat
#   inflating: __MACOSX/Resting/._s14_r.mat
#   inflating: Resting/s4_r.mat
#   inflating: __MACOSX/Resting/._s4_r.mat
#   inflating: Resting/s48_r.mat
#   inflating: __MACOSX/Resting/._s48_r.mat
#   inflating: Resting/s30_r.mat
#   inflating: __MACOSX/Resting/._s30_r.mat
#   inflating: Resting/s10_r.mat
#   inflating: __MACOSX/Resting/._s10_r.mat
#   inflating: Resting/s12_r.mat
#   inflating: __MACOSX/Resting/._s12_r.mat
#   inflating: Resting/s2_r.mat
#   inflating: __MACOSX/Resting/._s2_r.mat
#   inflating: Resting/s36_r.mat
#   inflating: __MACOSX/Resting/._s36_r.mat
#   inflating: Resting/s28_r.mat
#   inflating: __MACOSX/Resting/._s28_r.mat
#   inflating: Resting/s15_r.mat
#   inflating: __MACOSX/Resting/._s15_r.mat
#   inflating: Resting/s50_r.mat
#   inflating: __MACOSX/Resting/._s50_r.mat
#   inflating: Resting/s5_r.mat
#   inflating: __MACOSX/Resting/._s5_r.mat
#   inflating: Resting/s31_r.mat
#   inflating: __MACOSX/Resting/._s31_r.mat
#   inflating: Resting/s49_r.mat
#   inflating: __MACOSX/Resting/._s49_r.mat
#   inflating: Resting/s33_r.mat
#   inflating: __MACOSX/Resting/._s33_r.mat
#   inflating: Resting/s7_r.mat
#   inflating: __MACOSX/Resting/._s7_r.mat
#   inflating: Resting/s17_r.mat
#   inflating: __MACOSX/Resting/._s17_r.mat
#   inflating: Resting/s52_r.mat
#   inflating: __MACOSX/Resting/._s52_r.mat
#   inflating: Resting/s13_r.mat
#   inflating: __MACOSX/Resting/._s13_r.mat
#   inflating: Resting/s3_r.mat
#   inflating: __MACOSX/Resting/._s3_r.mat
#   inflating: Resting/s37_r.mat
#   inflating: __MACOSX/Resting/._s37_r.mat
#   inflating: Resting/s35_r.mat
#   inflating: __MACOSX/Resting/._s35_r.mat
#   inflating: Resting/s1_r.mat
#   inflating: __MACOSX/Resting/._s1_r.mat
#   inflating: Resting/s11_r.mat
#   inflating: __MACOSX/Resting/._s11_r.mat
#   inflating: Resting/s20_r.mat
#   inflating: __MACOSX/Resting/._s20_r.mat
#   inflating: Resting/s41_r.mat
#   inflating: __MACOSX/Resting/._s41_r.mat
#   inflating: Resting/s39_r.mat
#   inflating: __MACOSX/Resting/._s39_r.mat
#   inflating: Resting/s43_r.mat
#   inflating: __MACOSX/Resting/._s43_r.mat
#   inflating: Resting/s22_r.mat
#   inflating: __MACOSX/Resting/._s22_r.mat
#   inflating: Resting/s26_r.mat
#   inflating: __MACOSX/Resting/._s26_r.mat
#   inflating: Resting/s47_r.mat
#   inflating: __MACOSX/Resting/._s47_r.mat
#   inflating: Resting/s45_r.mat
#   inflating: __MACOSX/Resting/._s45_r.mat
#   inflating: Resting/s19_r.mat
#   inflating: __MACOSX/Resting/._s19_r.mat
#   inflating: Resting/s9_r.mat
#   inflating: __MACOSX/Resting/._s9_r.mat
#   inflating: Resting/s24_r.mat
#   inflating: __MACOSX/Resting/._s24_r.mat
#   inflating: Resting/s42_r.mat
#   inflating: __MACOSX/Resting/._s42_r.mat
#   inflating: Resting/s23_r.mat
#   inflating: __MACOSX/Resting/._s23_r.mat
#   inflating: Resting/s21_r.mat
#   inflating: __MACOSX/Resting/._s21_r.mat
#   inflating: Resting/s38_r.mat
#   inflating: __MACOSX/Resting/._s38_r.mat
#   inflating: Resting/s40_r.mat
#   inflating: __MACOSX/Resting/._s40_r.mat
#   inflating: Resting/s44_r.mat
#   inflating: __MACOSX/Resting/._s44_r.mat
#   inflating: Resting/s25_r.mat
#   inflating: __MACOSX/Resting/._s25_r.mat
#   inflating: Resting/s18_r.mat
#   inflating: __MACOSX/Resting/._s18_r.mat
#   inflating: Resting/s8_r.mat
#   inflating: __MACOSX/Resting/._s8_r.mat
#   inflating: Resting/s27_r.mat
#   inflating: __MACOSX/Resting/._s27_r.mat
#   inflating: Resting/s46_r.mat
#   inflating: __MACOSX/Resting/._s46_r.mat

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U git+https://github.com/UN-GCPDS/python-gcpds.utils.git > /dev/null
from gcpds.utils import loaddb
# Out:
#   Running command git clone -q https://github.com/UN-GCPDS/python-gcpds.utils.git /tmp/pip-req-build-0kzu7yx6

# %%
db = loaddb.GIGA('databases/GIGA')
db.load_subject(3)
db.get_data()
epochs = db.get_epochs()
epochs['left hand'].average().plot_topomap()
epochs['right hand'].average().plot_topomap();

# %%
Xraw, y = db.get_run(run=[0,1],  classes=['left hand', 'right hand'])
Xraw.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-19273699e4fb> in <module>()
# ----> 1 Xraw, y = db.get_run(run=[0,1],  classes=['left hand', 'right hand'])
#       2 Xraw.shape
#
# /usr/local/lib/python3.6/dist-packages/gcpds/utils/loaddb/loaddb.py in get_run(self, run, classes, channels, reject_bad_trials)
#      24         classes = self.format_class_selector(classes)
#      25         channels = self.format_channels_selectors(channels)
# ---> 26         super().get_run(run, classes, channels, reject_bad_trials)
#      27
#      28         # Index of starts of all cues
#
# /usr/local/lib/python3.6/dist-packages/gcpds/utils/loaddb/base.py in get_run(self, run, classes, channels, reject_bad_trials)
#     134     def get_run(self, run: int, classes: Union[int, str], channels=Union[int, str], reject_bad_trials: Optional[bool] = True) -> np.ndarray:
#     135         """"""
# --> 136         if run > self.runs:
#     137             raise Exception(f'The current user only have {self.runs} runs.')
#     138
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
db = loaddb.GIGA('databases/GIGA')

db.load_subject(3)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-09d29b10c7ef> in <module>()
#       1 db = loaddb.GIGA('databases/GIGA')
#       2
# ----> 3 db.load_subject(3)
#
# /usr/local/lib/python3.6/dist-packages/gcpds/utils/loaddb/loaddb.py in load_subject(self, subject, mode)
#      16     def load_subject(self, subject: int, mode: str = 'training') -> None:
#      17         """"""
# ---> 18         data = super().load_subject(subject, mode)
#      19         self.data = data['eeg'][0][0]
#      20
#
# /usr/local/lib/python3.6/dist-packages/gcpds/utils/loaddb/base.py in load_subject(self, subject, mode)
#     114         self.runs = self.metadata[f'runs_{mode}'][subject - 1]
#     115         # self.data = load_mat(self.path, filename_subject, fid)['eeg'][0][0]
# --> 116         return load_mat(self.path, filename_subject, fid, size)
#     117
#     118     # # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.6/dist-packages/gcpds/utils/loaddb/base.py in load_mat(path, mat, fid, size, overwrite)
#      31         if filepath.endswith('.mat'):
#      32             try:
# ---> 33                 return loadmat(filepath)
#      34             except ValueError:
#      35                 try:
#
# /usr/local/lib/python3.6/dist-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     216     with _open_file_context(file_name, appendmat) as f:
#     217         MR, _ = mat_reader_factory(f, **kwargs)
# --> 218         matfile_dict = MR.get_variables(variable_names)
#     219
#     220     if mdict is not None:
#
# /usr/local/lib/python3.6/dist-packages/scipy/io/matlab/mio5.py in get_variables(self, variable_names)
#     290                 continue
#     291             try:
# --> 292                 res = self.read_var_array(hdr, process)
#     293             except MatReadError as err:
#     294                 warnings.warn(
#
# /usr/local/lib/python3.6/dist-packages/scipy/io/matlab/mio5.py in read_var_array(self, header, process)
#     250            `process`.
#     251         '''
# --> 252         return self._matrix_reader.array_from_header(header, process)
#     253
#     254     def get_variables(self, variable_names=None):
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.array_from_header()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.array_from_header()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.read_struct()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.read_mi_matrix()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.array_from_header()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.read_real_complex()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.read_numeric()
#
# mio5_utils.pyx in scipy.io.matlab.mio5_utils.VarReader5.read_element()
#
# streams.pyx in scipy.io.matlab.streams.ZlibInputStream.read_string()
#
# streams.pyx in scipy.io.matlab.streams.ZlibInputStream.read_into()
#
# OSError: could not read bytes

# %%
j
# Out:
# 3

# %%
db = loaddb.GIGA('databases/GIGA')
indx = loadmat('Means_giga_mayo.mat')['S1'].ravel()


for j in indx:
  sbj = j
  try:     
    db.load_subject(j) 
    acc_runs=np.zeros((db.runs))
    Xraw = []
    y    = []
    for r in range(db.runs):
        x, yy = db.get_run(run=r,  classes=['left hand', 'right hand']) 
        Xraw.append(x)
        y.append(yy)
        X=np.asarray(Xraw).reshape(len(Xraw*40),64,-1)
        Y=np.asarray(y).reshape(len(Xraw*40),-1)
        print(X.shape, Y.shape)
  except:
    print(j)
# Out:
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# 48
# (40, 64, 3584) (40, 1)
# 8
# 18
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# (40, 64, 3584) (40, 1)
# 11
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# 44
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# 23
# (40, 64, 3584) (40, 1)
# 21
# 50
# 17
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# 47
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# 40
# 25
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# 33
# (40, 64, 3584) (40, 1)
# 52
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# 32
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# 36
# 39
# 31
# 30
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# 12
# (40, 64, 3584) (40, 1)
# (80, 64, 3584) (80, 1)
# (120, 64, 3584) (120, 1)
# (160, 64, 3584) (160, 1)
# (200, 64, 3584) (200, 1)
# 38

# %%
fs=512
db = loaddb.GIGA('databases/GIGA')
indx = loadmat('Means_giga_mayo.mat')['S1'].ravel()
Path_def='/content/drive/MyDrive/CX_Regression/codigos/giga/target_por_runs/'
# tau = 4
# overlap=1-0.5
# ti = 4
# tf = 40
# tti = np.arange(ti,tf-tau+(tau*overlap),tau*overlap)
# ttf = np.arange(ti+tau,tf+tau*overlap,tau*overlap)
#f_frec =np.array([tti,ttf]).T
f_frec = np.array([[8,12],[12,25]]) #np.array([tti,ttf]).T 
##
tau =  2   # tamaño de la ventana.
step = 0.5 # overlap esta en seg.
ti = 2     # inicio de la ventana.
tf = 6     # fin de la ventana.
tti = np.arange(ti,tf-tau+(step),step)
ttf = np.arange(ti+tau,tf+step,step)
vtw = np.array([tti,ttf]).T

acc_subj=[]

for j in indx:
    sbj = j    
    db.load_subject(j) 
    acc_runs=np.zeros((db.runs))
    for r in range(db.runs):
        Xraw, y = db.get_run(run=r,  classes=['left hand', 'right hand']) 

        #opt = tf.keras.optimizers.RMSprop(learning_rate=1e-1)
        steps=[('CSP_window_time',Window_band_CSP_eppoch(fs=fs,vtw=vtw,f_frec=f_frec)),
              ('flat',flatt()),
              ('stand',StandardScaler()),
              ('proy',Lasso_feats()),
              ('cla', LDA())]
        method = Pipeline(steps,memory='datospipeline')
        parameters ={'CSP_window_time__ncomp':[6],
                'proy__alpha':[1e-5,0.2,0.4]}
        scores = {'acc': 'accuracy','kappa': make_scorer(cohen_kappa_score,greater_is_better=True)}    
        cv = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=0)
        grid_search = GridSearchCV(method, parameters,cv=cv,verbose=10,
                                  scoring=scores,refit='acc',n_jobs=-1)
        #grid_search = GridSearchCV(method, parameters,cv=cv,verbose=10,
        #                          scoring=kappa_,n_jobs=-1)
        #try:
        grid_search.fit(Xraw,y)
        results = grid_search.cv_results_
        filters = grid_search.best_estimator_['CSP_window_time'].filters
        ncomp = grid_search.best_estimator_['CSP_window_time'].ncomp
        max_acc = np.max(results['mean_test_acc'])
        savedata ={
              
            'steps':steps,
            'f_frec':f_frec,
            'vtw':vtw,
            'best_param':grid_search.best_params_,               
            'cv_results':results,
            'max_acc':max_acc
        }
        
        print('sub:  '+str(sbj)+' acc: '+str(max_acc) )

        with open(Path_def+'results_acc_giga'+str(tau)+'seg_'+str(vtw.shape[0])+'time_'+str(f_frec.shape[0])+'frec_'+str(sbj)+'run_'+str(sbj)+'.p','wb') as handle:
                    pickle.dump(savedata,handle)
        acc_runs[r] = max_acc
    acc_subj.append(acc_runs)

    taget_phy={
        'acc_subj':acc_subj,
        'indx':indx }

    with open(Path_def+'target_giga_'+str(tau)+'seg_'+str(vtw.shape[0])+'time_'+str(f_frec.shape[0])+'frec.p','wb') as handle:
                      pickle.dump(taget_phy,handle)
# Out:
# WARNING:root:Database not found!
# WARNING:root:downloading...
# Downloading 1-EZGtgl_miuqQosDFgokb0aqcqO9ilkM into databases/GIGA/s01.mat...
# HBox(children=(FloatProgress(value=0.0, description='databases/GIGA/s01.mat', max=6208.68701171875, style=Prog…
# Done.
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   36.6s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   37.8s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   39.2s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   41.0s finished
# sub:  43 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   38.0s finished
# sub:  43 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   37.2s finished
# sub:  43 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   36.4s finished
# sub:  43 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   37.4s finished
# sub:  43 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  14 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  14 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  14 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  14 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  14 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  3 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  3 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  3 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  3 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  3 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  48 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  48 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  48 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  48 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  48 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  41 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  41 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  41 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  41 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  41 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  50 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  50 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  50 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  50 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  50 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  23 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  23 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  23 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  23 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  23 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  35 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  35 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  35 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  35 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  35 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  4 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  4 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  4 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  4 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.5s finished
# sub:  4 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  10 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  10 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  10 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  10 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  10 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  44 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  44 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  44 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  44 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  44 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  6 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  6 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  6 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  6 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  6 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  15 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  15 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  15 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  15 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  15 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  5 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  5 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  5 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  5 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  5 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  49 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  49 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  49 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  49 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  49 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  21 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  21 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  21 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# sub:  21 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  21 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  26 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  26 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.5s finished
# sub:  26 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  26 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  26 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  46 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  46 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  46 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# ...
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  2 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  2 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  2 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  2 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  2 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  7 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  7 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  7 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  7 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  7 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  40 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  40 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  40 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  40 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  40 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  33 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.5s finished
# sub:  33 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  33 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  33 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  33 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  8 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  8 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  8 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  8 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
# sub:  8 acc: 0.5875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  17 acc: 0.6625
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.2s finished
# sub:  17 acc: 0.6125
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  17 acc: 0.65
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
# sub:  17 acc: 0.6875
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# sub:  17 acc: 0.5875
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished

# %%
len(acc_subj)
# Out:
# 300

# %%
y.shape
# Out:
# (40,)

# %%
FILEID = "1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O phy_cxregression_3frec.p && rm -rf /tmp/cookies.txt
# !dir
results = pickle.load( open( "phy_cxregression_3frec.p", "rb" ) )
plt.plot(results['y_origi'])
# Out:
# --2021-01-16 23:57:36--  https://docs.google.com/uc?export=download&confirm=&id=1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP
# Resolving docs.google.com (docs.google.com)... 108.177.98.102, 108.177.98.138, 108.177.98.101, ...
# Connecting to docs.google.com (docs.google.com)|108.177.98.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e=download [following]
# --2021-01-16 23:57:36--  https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e=download
# Resolving doc-0s-64-docs.googleusercontent.com (doc-0s-64-docs.googleusercontent.com)... 74.125.195.132, 2607:f8b0:400e:c09::84
# Connecting to doc-0s-64-docs.googleusercontent.com (doc-0s-64-docs.googleusercontent.com)|74.125.195.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=e8380gssvghts&continue=https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e%3Ddownload&hash=uqkkm8qnt07pl4894hosvaq5ua0g1ehl [following]
# --2021-01-16 23:57:36--  https://docs.google.com/nonceSigner?nonce=e8380gssvghts&continue=https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e%3Ddownload&hash=uqkkm8qnt07pl4894hosvaq5ua0g1ehl
# Connecting to docs.google.com (docs.google.com)|108.177.98.102|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e=download&nonce=e8380gssvghts&user=12652593867932649914Z&hash=19tt54r3t0tkpv7q1i14eav3i2sfs3pn [following]
# --2021-01-16 23:57:36--  https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e=download&nonce=e8380gssvghts&user=12652593867932649914Z&hash=19tt54r3t0tkpv7q1i14eav3i2sfs3pn
# Connecting to doc-0s-64-docs.googleusercontent.com (doc-0s-64-docs.googleusercontent.com)|74.125.195.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2923 (2.9K) [text/x-pascal]
# Saving to: ‘phy_cxregression_3frec.p’
#
# phy_cxregression_3f 100%[===================>]   2.85K  --.-KB/s    in 0s
#
# 2021-01-16 23:57:36 (143 MB/s) - ‘phy_cxregression_3frec.p’ saved [2923/2923]
#
# CKA_keras.py   MIfunctions.py		 physionet.zip
# datospipeline  phy_cxregression_3frec.p  __pycache__
# drive	       physionet		 sample_data

# %%
load = pickle.load( open( "/content/drive/MyDrive/CX_Regression/codigos/physionet/targets_physionet/results_acc_2seg_5time_2frec_S096.p", "rb" ) )

# %%
load['cv_results']['mean_test_acc']
# Out:
# array([0.42222222, 0.51111111,        nan])

# %%
int(indx[0][1::])
# Out:
# 91

# %%
indx2=[int(indx[i][1::]) for i in range(len(indx))]
indx2
# Out:
# [91,
#  98,
#  59,
#  1,
#  38,
#  81,
#  7,
#  18,
#  54,
#  12,
#  41,
#  60,
#  3,
#  39,
#  109,
#  72,
#  89,
#  43,
#  78,
#  21,
#  97,
#  55,
#  94,
#  77,
#  24,
#  25,
#  90,
#  56,
#  74,
#  14,
#  15,
#  69,
#  37,
#  40,
#  84,
#  20,
#  79,
#  105,
#  101,
#  10,
#  17,
#  67,
#  104,
#  46,
#  71,
#  63,
#  28,
#  102,
#  13,
#  66,
#  49,
#  73,
#  68,
#  2,
#  4,
#  53,
#  76,
#  96,
#  32,
#  108,
#  11,
#  93,
#  35,
#  5,
#  23,
#  80,
#  47,
#  95,
#  51,
#  27,
#  6,
#  33,
#  45,
#  52,
#  61,
#  48,
#  64,
#  57,
#  65,
#  86,
#  50,
#  42,
#  103,
#  44,
#  30,
#  16,
#  75,
#  36,
#  26,
#  31,
#  70,
#  58,
#  8,
#  107,
#  87,
#  99,
#  106,
#  62,
#  19,
#  22,
#  34,
#  83,
#  85,
#  29,
#  82,
#  9]

# %%
=plt.plot(np.flip(np.sort(acc_subj))*100)
plt.plot(results['y_origi'])

# %%
np.sort(np.asarray(acc_subj))
# Out:
# array([0.41111111, 0.42222222, 0.43333333, 0.43333333, 0.44444444,
#        0.44444444, 0.45555556, 0.46666667, 0.46666667, 0.46666667,
#        0.47777778, 0.47777778, 0.47777778, 0.47777778, 0.47777778,
#        0.48888889, 0.48888889, 0.48888889, 0.48888889, 0.48888889,
#        0.48888889, 0.5       , 0.5       , 0.5       , 0.5       ,
#        0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#        0.51111111, 0.51111111, 0.51111111, 0.51111111, 0.51111111,
#        0.51111111, 0.51111111, 0.51111111, 0.51111111, 0.52222222,
#        0.52222222, 0.52222222, 0.52222222, 0.52222222, 0.52222222,
#        0.52222222, 0.52222222, 0.53333333, 0.54444444, 0.54444444,
#        0.54444444, 0.54444444, 0.54444444, 0.54444444, 0.54444444,
#        0.54444444, 0.55555556, 0.55555556, 0.55555556, 0.56666667,
#        0.56666667, 0.56666667, 0.57777778, 0.57777778, 0.57777778,
#        0.57777778, 0.57777778, 0.57777778, 0.57777778, 0.57777778,
#        0.57777778, 0.57777778, 0.57777778, 0.58888889, 0.58888889,
#        0.58888889, 0.58888889, 0.6       , 0.6       , 0.6       ,
#        0.6       , 0.6       , 0.61111111, 0.61111111, 0.61111111,
#        0.61111111, 0.61111111, 0.62222222, 0.62222222, 0.63333333,
#        0.6375    , 0.64444444, 0.66666667, 0.66666667, 0.68888889,
#        0.68888889, 0.71111111, 0.72222222, 0.74444444, 0.75555556,
#        0.75555556, 0.78888889, 0.8       , 0.83333333, 0.87777778,
#        0.97777778])

# %%
IN=np.asarray(indx)
np.flip(IN[np.argsort(np.asarray(acc_subj))])
# Out:
# array(['S029', 'S007', 'S094', 'S054', 'S042', 'S072', 'S056', 'S062',
#        'S048', 'S015', 'S031', 'S070', 'S040', 'S032', 'S034', 'S104',
#        'S085', 'S035', 'S068', 'S073', 'S063', 'S012', 'S019', 'S108',
#        'S002', 'S093', 'S074', 'S049', 'S018', 'S045', 'S091', 'S022',
#        'S008', 'S069', 'S077', 'S053', 'S050', 'S021', 'S011', 'S071',
#        'S055', 'S017', 'S080', 'S060', 'S095', 'S009', 'S043', 'S025',
#        'S010', 'S066', 'S037', 'S097', 'S083', 'S109', 'S102', 'S075',
#        'S081', 'S003', 'S082', 'S041', 'S099', 'S076', 'S023', 'S089',
#        'S052', 'S044', 'S105', 'S014', 'S086', 'S004', 'S107', 'S006',
#        'S106', 'S046', 'S013', 'S096', 'S001', 'S033', 'S027', 'S047',
#        'S039', 'S078', 'S067', 'S061', 'S036', 'S058', 'S026', 'S103',
#        'S090', 'S087', 'S038', 'S084', 'S098', 'S065', 'S057', 'S005',
#        'S059', 'S020', 'S101', 'S024', 'S079', 'S051', 'S016', 'S030',
#        'S028', 'S064'], dtype='<U4')

# %%
mean_std= ['mean_test_acc' , 'std_test_acc']
mean_std[]
# Out:
# ['mean_test_acc', 'std_test_acc']

# %%
import time
for i in range(len(listdir)):
    if listdir[i] == 'S096':
        print('Pos '+str(i)+' Sub '+str(listdir[i]))
        taget_phy['indx'][i]
# Out:
# Pos 57 Sub S096

# %% [markdown]
# Topoplots

# %%
tau =  4
overlap=1-0.5
ti = 4
tf = 40
tti = np.arange(ti,tf-tau+(tau*overlap),tau*overlap)
ttf = np.arange(ti+tau,tf+tau*overlap,tau*overlap)
f_frec = np.array([tti,ttf]).T

tau =  2
step = 0.5
ti = 2
tf = 6
tti = np.arange(ti,tf-tau+(step),step)
ttf = np.arange(ti+tau,tf+step,step)
vtw = np.array([tti,ttf]).T

j = 51
sbj = listdir[j]
XX = loadmat('../input/gcpds-physionet/'+sbj+'/eeg/raw.mat')
data=XX['X']
data[0][0].shape
Xraw = np.array([data[0][j] for j in range(len(data[0]))])
fs = XX['fs'][0][0]
ch = XX['channels'][0]
channels_names = [ch[c][0] for c in range(len(ch))]
yy = XX['y']
y = np.array([yy[j][0] for j in range(len(yy))])-1
# montage = mne.channels.read_montage(db.metadata['montage'], channels_names)
# info = mne.create_info(channels_names, sfreq=fs, ch_types="eeg",montage=montage)

# %%
import mne
import numpy as np
from typing import List

def get_epochs(data: np.ndarray, classes: np.ndarray,  labels:List[str], 
               tmin:int, montage_name:str, sampling_rate:int, 
               channels_names:List[str], **kwargs) -> mne.EpochsArray:
    """
    Creates a `mne.Epochs` with their respective montage information from raw data.
    
    Parameters
    ----------
    
    data
        Numpy array with the shape (trials, channels, time).
    classes
        Numpy array with the labels as integers.
    labels
        The label descriptor for each class.
    tmin
        Time in seconds before the event, is used to center the event in t=0,
        is negative.
    montage_name
        One of the montages defined in `mne.channels.get_builtin_montages()`.
    sampling_rate
        Sample frecuency.
    channels_names
        List of channels names, no matter the capitalization.

    Returns
    -------
    epochs
        The `mne.EpochsArray` object.
    """

    montage = mne.channels.make_standard_montage(montage_name)

    # Channels names with the MNE standard capitalization 
    source = channels_names
    target = montage.ch_names
    channels_names = []
    for ch_s in source:
        for ch_t in target:
            if ch_s.lower().strip() == ch_t.lower().strip():
                channels_names.append(ch_t)

    # Missing channels
    channels_missings = set(channels_names).difference(set(montage.ch_names))
    if channels_missings:
        print(f"Missing {channels_missings} channels in {montage_name} montage.\n"
              f"Missing channels will be removed from MNE Epochs")

    # Info
    info = mne.create_info(list(channels_names), sfreq=sampling_rate, ch_types="eeg")
    info.set_montage(montage_name)

    # Events
    events = [[i, 1, cls] for i, cls in enumerate(classes)]
    event_id = {e: i for i, e in enumerate(labels)}

    return mne.EpochsArray(data, info, events=events, tmin=tmin, event_id=event_id, **kwargs)

# %%
epochs = get_epochs(data=Xraw, classes=y, labels=['right hand', 'left hand'], tmin=-2, montage_name='standard_1005', sampling_rate=fs, channels_names=channels_names)

# %%
montage = epochs.get_montage()
montage.plot(kind='topomap', show_names=True)

evoked = epochs['izq'].average()

fig = plt.figure(figsize=(10, 5), dpi=90)
ax = plt.subplot(111)
evoked.plot(axes=ax, spatial_colors=True);

# %%
times = np.linspace(0, 4, 6)

epochs['a'].average().plot_topomap(times,)
