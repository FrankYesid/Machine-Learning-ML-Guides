# %%
# !pip install mne==0.19
# !pip install -U git+https://github.com/UN-GCPDS/python-gcpds.utils.git
from gcpds.utils import loaddb
# Out:
# Collecting mne==0.19
#   Downloading https://files.pythonhosted.org/packages/f5/44/b5b96426623c9dca0dfcdcfdf1f57058bb668f7c1a01bed0b0b867eb8b92/mne-0.19.0-py3-none-any.whl (6.4MB)
#      |████████████████████████████████| 6.4MB 6.5MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from mne==0.19) (1.19.5)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from mne==0.19) (1.4.1)
# Installing collected packages: mne
# Successfully installed mne-0.19.0
# Collecting git+https://github.com/UN-GCPDS/python-gcpds.utils.git
#   Cloning https://github.com/UN-GCPDS/python-gcpds.utils.git to /tmp/pip-req-build-msl9tclz
#   Running command git clone -q https://github.com/UN-GCPDS/python-gcpds.utils.git /tmp/pip-req-build-msl9tclz
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from gcpds-utils==0.1a3) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.7/dist-packages (from gcpds-utils==0.1a3) (1.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib in /usr/local/lib/python3.7/dist-packages (from gcpds-utils==0.1a3) (3.2.2)
# Requirement already satisfied, skipping upgrade: mne in /usr/local/lib/python3.7/dist-packages (from gcpds-utils==0.1a3) (0.19.0)
# Requirement already satisfied, skipping upgrade: tables in /usr/local/lib/python3.7/dist-packages (from gcpds-utils==0.1a3) (3.4.4)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from gcpds-utils==0.1a3) (4.41.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->gcpds-utils==0.1a3) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->gcpds-utils==0.1a3) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->gcpds-utils==0.1a3) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->gcpds-utils==0.1a3) (1.3.1)
# Requirement already satisfied, skipping upgrade: numexpr>=2.5.2 in /usr/local/lib/python3.7/dist-packages (from tables->gcpds-utils==0.1a3) (2.7.3)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from tables->gcpds-utils==0.1a3) (1.15.0)
# Building wheels for collected packages: gcpds-utils
#   Building wheel for gcpds-utils (setup.py) ... done
#   Created wheel for gcpds-utils: filename=gcpds_utils-0.1a3-cp37-none-any.whl size=114497 sha256=0b2150583fd5164e2e188bec8d0ece562a376fb906ec9818b7b566e25d616ea6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d15z_2fx/wheels/ab/4a/1e/d215a31a12c0fa202a9bccc9b9d68874deb08dfdce8b7d43c8
# Successfully built gcpds-utils
# Installing collected packages: gcpds-utils
# Successfully installed gcpds-utils-0.1a3

# %%
FILEID = "1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O CKA_keras.py && rm -rf /tmp/cookies.txt
# !dir
# Out:
# --2021-03-23 21:57:19--  https://docs.google.com/uc?export=download&confirm=&id=1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK
# Resolving docs.google.com (docs.google.com)... 108.177.98.113, 108.177.98.102, 108.177.98.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.98.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-2g-docs.googleusercontent.com/docs/securesc/j9tuu268ja319anqtu8h5sdpembvti0n/af1irpqpmmk6de92kod83epa7edott4g/1616536575000/06932581800131476027/09299483386603303718Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e=download [following]
# --2021-03-23 21:57:20--  https://doc-0c-2g-docs.googleusercontent.com/docs/securesc/j9tuu268ja319anqtu8h5sdpembvti0n/af1irpqpmmk6de92kod83epa7edott4g/1616536575000/06932581800131476027/09299483386603303718Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e=download
# Resolving doc-0c-2g-docs.googleusercontent.com (doc-0c-2g-docs.googleusercontent.com)... 74.125.20.132, 2607:f8b0:400e:c07::84
# Connecting to doc-0c-2g-docs.googleusercontent.com (doc-0c-2g-docs.googleusercontent.com)|74.125.20.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=bee5dc5t76q22&continue=https://doc-0c-2g-docs.googleusercontent.com/docs/securesc/j9tuu268ja319anqtu8h5sdpembvti0n/af1irpqpmmk6de92kod83epa7edott4g/1616536575000/06932581800131476027/09299483386603303718Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e%3Ddownload&hash=ouqcijo990s95m3j67g8dirf39fanupt [following]
# --2021-03-23 21:57:20--  https://docs.google.com/nonceSigner?nonce=bee5dc5t76q22&continue=https://doc-0c-2g-docs.googleusercontent.com/docs/securesc/j9tuu268ja319anqtu8h5sdpembvti0n/af1irpqpmmk6de92kod83epa7edott4g/1616536575000/06932581800131476027/09299483386603303718Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e%3Ddownload&hash=ouqcijo990s95m3j67g8dirf39fanupt
# Connecting to docs.google.com (docs.google.com)|108.177.98.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0c-2g-docs.googleusercontent.com/docs/securesc/j9tuu268ja319anqtu8h5sdpembvti0n/af1irpqpmmk6de92kod83epa7edott4g/1616536575000/06932581800131476027/09299483386603303718Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e=download&nonce=bee5dc5t76q22&user=09299483386603303718Z&hash=l0t1cs1isfoi1oouojthb1j78anbtfgc [following]
# --2021-03-23 21:57:20--  https://doc-0c-2g-docs.googleusercontent.com/docs/securesc/j9tuu268ja319anqtu8h5sdpembvti0n/af1irpqpmmk6de92kod83epa7edott4g/1616536575000/06932581800131476027/09299483386603303718Z/1A2a60KUPxtUboqlb8B6Q0U-OygVmS_wK?e=download&nonce=bee5dc5t76q22&user=09299483386603303718Z&hash=l0t1cs1isfoi1oouojthb1j78anbtfgc
# Connecting to doc-0c-2g-docs.googleusercontent.com (doc-0c-2g-docs.googleusercontent.com)|74.125.20.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7401 (7.2K) [text/plain]
# Saving to: ‘CKA_keras.py’
#
# CKA_keras.py        100%[===================>]   7.23K  --.-KB/s    in 0s
#
# 2021-03-23 21:57:20 (65.6 MB/s) - ‘CKA_keras.py’ saved [7401/7401]
#
# CKA_keras.py  sample_data

# %%
! pip install bctpy
! pip install mne==0.19
#funciones de Daniel
FILEID = "1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O MIfunctions.py && rm -rf /tmp/cookies.txt

FILEID = "1F9WpS7sKSFY73HSHYBgYXw9iyYalBKgh" 
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O modCSP.py && rm -rf /tmp/cookies.txt
# Out:
# Collecting bctpy
#   Downloading https://files.pythonhosted.org/packages/9a/46/7042010c316b20631613644b844c15c8369066ca1be9e430f6619f4af562/bctpy-0.5.2-py3-none-any.whl (102kB)
#      |████████████████████████████████| 112kB 8.0MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from bctpy) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from bctpy) (1.19.5)
# Installing collected packages: bctpy
# Successfully installed bctpy-0.5.2
# Requirement already satisfied: mne==0.19 in /usr/local/lib/python3.7/dist-packages (0.19.0)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from mne==0.19) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from mne==0.19) (1.19.5)
# --2021-03-23 21:58:37--  https://docs.google.com/uc?export=download&confirm=&id=1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG
# Resolving docs.google.com (docs.google.com)... 108.177.98.102, 108.177.98.101, 108.177.98.100, ...
# Connecting to docs.google.com (docs.google.com)|108.177.98.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-9c-docs.googleusercontent.com/docs/securesc/7mvpmsfvhts7q23hhvsub8fmt690jtpc/rq5jb9q8qk4dipkbum96idjse03ttvuo/1616536650000/06932581800131476027/17428682607720219743Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e=download [following]
# --2021-03-23 21:58:37--  https://doc-14-9c-docs.googleusercontent.com/docs/securesc/7mvpmsfvhts7q23hhvsub8fmt690jtpc/rq5jb9q8qk4dipkbum96idjse03ttvuo/1616536650000/06932581800131476027/17428682607720219743Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e=download
# Resolving doc-14-9c-docs.googleusercontent.com (doc-14-9c-docs.googleusercontent.com)... 74.125.20.132, 2607:f8b0:400e:c07::84
# Connecting to doc-14-9c-docs.googleusercontent.com (doc-14-9c-docs.googleusercontent.com)|74.125.20.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=u98v2f068ktf8&continue=https://doc-14-9c-docs.googleusercontent.com/docs/securesc/7mvpmsfvhts7q23hhvsub8fmt690jtpc/rq5jb9q8qk4dipkbum96idjse03ttvuo/1616536650000/06932581800131476027/17428682607720219743Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e%3Ddownload&hash=d00a1jn64vnmd4p4dtmpqv7jisbflklv [following]
# --2021-03-23 21:58:37--  https://docs.google.com/nonceSigner?nonce=u98v2f068ktf8&continue=https://doc-14-9c-docs.googleusercontent.com/docs/securesc/7mvpmsfvhts7q23hhvsub8fmt690jtpc/rq5jb9q8qk4dipkbum96idjse03ttvuo/1616536650000/06932581800131476027/17428682607720219743Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e%3Ddownload&hash=d00a1jn64vnmd4p4dtmpqv7jisbflklv
# Connecting to docs.google.com (docs.google.com)|108.177.98.102|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-14-9c-docs.googleusercontent.com/docs/securesc/7mvpmsfvhts7q23hhvsub8fmt690jtpc/rq5jb9q8qk4dipkbum96idjse03ttvuo/1616536650000/06932581800131476027/17428682607720219743Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e=download&nonce=u98v2f068ktf8&user=17428682607720219743Z&hash=997jf5kt9kavsiohng4k3o36mi2p0cps [following]
# --2021-03-23 21:58:37--  https://doc-14-9c-docs.googleusercontent.com/docs/securesc/7mvpmsfvhts7q23hhvsub8fmt690jtpc/rq5jb9q8qk4dipkbum96idjse03ttvuo/1616536650000/06932581800131476027/17428682607720219743Z/1DOm75xoSPUbnFfcJBjVggPS0hzNEoWCG?e=download&nonce=u98v2f068ktf8&user=17428682607720219743Z&hash=997jf5kt9kavsiohng4k3o36mi2p0cps
# Connecting to doc-14-9c-docs.googleusercontent.com (doc-14-9c-docs.googleusercontent.com)|74.125.20.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49431 (48K) [text/x-python]
# Saving to: ‘MIfunctions.py’
#
# MIfunctions.py      100%[===================>]  48.27K  --.-KB/s    in 0s
#
# 2021-03-23 21:58:38 (104 MB/s) - ‘MIfunctions.py’ saved [49431/49431]
#
# --2021-03-23 21:58:39--  https://docs.google.com/uc?export=download&confirm=&id=1F9WpS7sKSFY73HSHYBgYXw9iyYalBKgh
# Resolving docs.google.com (docs.google.com)... 74.125.195.139, 74.125.195.113, 74.125.195.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.195.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-cc-docs.googleusercontent.com/docs/securesc/bjhsgtj24q6ordn2qqaoi4vntkivo710/iplk9aho4vm34kcru13et0rqnvf5cbra/1616536650000/06932581800131476027/09939412530184288182Z/1F9WpS7sKSFY73HSHYBgYXw9iyYalBKgh?e=download [following]
# --2021-03-23 21:58:39--  https://doc-04-cc-docs.googleusercontent.com/docs/securesc/bjhsgtj24q6ordn2qqaoi4vntkivo710/iplk9aho4vm34kcru13et0rqnvf5cbra/1616536650000/06932581800131476027/09939412530184288182Z/1F9WpS7sKSFY73HSHYBgYXw9iyYalBKgh?e=download
# Resolving doc-04-cc-docs.googleusercontent.com (doc-04-cc-docs.googleusercontent.com)... 74.125.20.132, 2607:f8b0:400e:c07::84
# Connecting to doc-04-cc-docs.googleusercontent.com (doc-04-cc-docs.googleusercontent.com)|74.125.20.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=a66ivnn0tj9hc&continue=https://doc-04-cc-docs.googleusercontent.com/docs/securesc/bjhsgtj24q6ordn2qqaoi4vntkivo710/iplk9aho4vm34kcru13et0rqnvf5cbra/1616536650000/06932581800131476027/09939412530184288182Z/1F9WpS7sKSFY73HSHYBgYXw9iyYalBKgh?e%3Ddownload&hash=a3p74ncapo9qv1rl0kvm506omekdj30o [following]
# --2021-03-23 21:58:39--  https://docs.google.com/nonceSigner?nonce=a66ivnn0tj9hc&continue=https://doc-04-cc-docs.googleusercontent.com/docs/securesc/bjhsgtj24q6ordn2qqaoi4vntkivo710/iplk9aho4vm34kcru13et0rqnvf5cbra/1616536650000/06932581800131476027/09939412530184288182Z/1F9WpS7sKSFY73HSHYBgYXw9iyYalBKgh?e%3Ddownload&hash=a3p74ncapo9qv1rl0kvm506omekdj30o
# Connecting to docs.google.com (docs.google.com)|74.125.195.139|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-04-cc-docs.googleusercontent.com/docs/securesc/bjhsgtj24q6ordn2qqaoi4vntkivo710/iplk9aho4vm34kcru13et0rqnvf5cbra/1616536650000/06932581800131476027/09939412530184288182Z/1F9WpS7sKSFY73HSHYBgYXw9iyYalBKgh?e=download&nonce=a66ivnn0tj9hc&user=09939412530184288182Z&hash=c135kscsoc5b17k9k8iko7bdh727n59g [following]
# --2021-03-23 21:58:39--  https://doc-04-cc-docs.googleusercontent.com/docs/securesc/bjhsgtj24q6ordn2qqaoi4vntkivo710/iplk9aho4vm34kcru13et0rqnvf5cbra/1616536650000/06932581800131476027/09939412530184288182Z/1F9WpS7sKSFY73HSHYBgYXw9iyYalBKgh?e=download&nonce=a66ivnn0tj9hc&user=09939412530184288182Z&hash=c135kscsoc5b17k9k8iko7bdh727n59g
# Connecting to doc-04-cc-docs.googleusercontent.com (doc-04-cc-docs.googleusercontent.com)|74.125.20.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41586 (41K) [text/plain]
# Saving to: ‘modCSP.py’
#
# modCSP.py           100%[===================>]  40.61K  --.-KB/s    in 0s
#
# 2021-03-23 21:58:39 (124 MB/s) - ‘modCSP.py’ saved [41586/41586]

# %%
from gcpds.utils import loaddb
import sys
from scipy.io import loadmat,savemat
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import numpy as np
from joblib import dump, load
from sklearn.svm import LinearSVC, SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split,GridSearchCV, StratifiedShuffleSplit
from mne.viz import plot_topomap
#from keras_cka_v3 import Keras_CKA # import keras_cka function wrapped for sklearn.
from CKA_keras import Keras_CKA # import keras_cka function wrapped for sklearn.
from MIfunctions import * #importar todas las funciones de manejo de eeg con mne.
import os
import time
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, cohen_kappa_score, pairwise_distances
from sklearn.metrics import make_scorer
import pickle

# %%
FILEID = "1tIAIAymOYi3gK7HtPoGi0Y6X6lpo-H_3"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O Data_rest_r0.zip && rm -rf /tmp/cookies.txt
# !dir
# !unzip Data_rest_r0.zip

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
db = loaddb.GIGA_MI_ME('/content/drive/Shareddrives/GCPDS/databases/GIGA-MI_ME')
fs=512
db.load_subject(1)
x, y = db.get_data()
# Out:
# WARNING:GCPDS:utils:The directory folder is optional for Google Drive mounted environment.

# %%
Path_def='/content/drive/MyDrive/CX_Regression/codigos/giga/target_giga/'
fs=512

#indx = loadmat('Means_giga_mayo.mat')['S1'].ravel()

# tau = 4
# overlap=1-0.5
# ti = 4
# tf = 40
# tti = np.arange(ti,tf-tau+(tau*overlap),tau*overlap)
# ttf = np.arange(ti+tau,tf+tau*overlap,tau*overlap)
#f_frec =np.array([tti,ttf]).T
f_frec = np.array([[8,12],[12,25]]) #np.array([tti,ttf]).T 
##
tau =  2   # tamaño de la ventana.
step = 0.5 # overlap esta en seg.
ti = 2     # inicio de la ventana.
tf = 6     # fin de la ventana.
tti = np.arange(ti,tf-tau+(step),step)
ttf = np.arange(ti+tau,tf+step,step)
vtw = np.array([tti,ttf]).T

acc_subj = []

for j in [17]:
    sbj = j
    db.load_subject(j)
    Xraw, y = db.get_data()  
    
    
    #opt = tf.keras.optimizers.RMSprop(learning_rate=1e-1)
    steps=[('CSP_window_time',Window_band_CSP_eppoch(fs=fs,vtw=vtw,f_frec=f_frec)),
          ('flat',flatt()),
          ('stand',StandardScaler()),
          ('proy',Lasso_feats()),
           ('cla', LDA())]
    method = Pipeline(steps,memory='datospipeline')
    parameters ={'CSP_window_time__ncomp':[6],
            'proy__alpha':[1e-5,0.2,0.4]}
    scores = {'acc': 'accuracy','kappa': make_scorer(cohen_kappa_score,greater_is_better=True)}    
    cv = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=0)
    grid_search = GridSearchCV(method, parameters,cv=cv,verbose=10,
                               scoring=scores,refit='acc',n_jobs=-1)
    #grid_search = GridSearchCV(method, parameters,cv=cv,verbose=10,
     #                          scoring=kappa_,n_jobs=-1)
    #try:
    grid_search.fit(Xraw,y)
    results = grid_search.cv_results_
    filters = grid_search.best_estimator_['CSP_window_time'].filters
    ncomp = grid_search.best_estimator_['CSP_window_time'].ncomp
    max_acc = np.max(results['mean_test_acc'])
    savedata ={
           
        'steps':steps,
        'f_frec':f_frec,
        'vtw':vtw,
        'best_param':grid_search.best_params_,               
        'cv_results':results,
        'max_acc':max_acc
    }
    acc_subj.append(max_acc)
    print('sub:  '+str(sbj)+' acc: '+str(max_acc) )
    
    with open(Path_def+'results_acc_'+str(tau)+'seg_'+str(vtw.shape[0])+'time_'+str(f_frec.shape[0])+'frec_'+str(sbj)+'.p','wb') as handle:
               pickle.dump(savedata,handle)

taget_phy={
    'acc_subj':acc_subj,
    'indx':indx   
    
}

with open(Path_def+'target_giga_'+str(tau)+'seg_'+str(vtw.shape[0])+'time_'+str(f_frec.shape[0])+'frec.p','wb') as handle:
                pickle.dump(taget_phy,handle)
# Out:
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  3.9min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-ba3c9bde197d> in <module>()
#      47      #                          scoring=kappa_,n_jobs=-1)
#      48     #try:
# ---> 49     grid_search.fit(Xraw,y)
#      50     results = grid_search.cv_results_
#      51     filters = grid_search.best_estimator_['CSP_window_time'].filters
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
Xraw.shape
# Out:
# (40, 64, 3584)

# %%
y.shape
# Out:
# (40,)

# %%
FILEID = "1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O phy_cxregression_3frec.p && rm -rf /tmp/cookies.txt
# !dir
results = pickle.load( open( "phy_cxregression_3frec.p", "rb" ) )
plt.plot(results['y_origi'])
# Out:
# --2021-01-16 23:57:36--  https://docs.google.com/uc?export=download&confirm=&id=1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP
# Resolving docs.google.com (docs.google.com)... 108.177.98.102, 108.177.98.138, 108.177.98.101, ...
# Connecting to docs.google.com (docs.google.com)|108.177.98.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e=download [following]
# --2021-01-16 23:57:36--  https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e=download
# Resolving doc-0s-64-docs.googleusercontent.com (doc-0s-64-docs.googleusercontent.com)... 74.125.195.132, 2607:f8b0:400e:c09::84
# Connecting to doc-0s-64-docs.googleusercontent.com (doc-0s-64-docs.googleusercontent.com)|74.125.195.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=e8380gssvghts&continue=https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e%3Ddownload&hash=uqkkm8qnt07pl4894hosvaq5ua0g1ehl [following]
# --2021-01-16 23:57:36--  https://docs.google.com/nonceSigner?nonce=e8380gssvghts&continue=https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e%3Ddownload&hash=uqkkm8qnt07pl4894hosvaq5ua0g1ehl
# Connecting to docs.google.com (docs.google.com)|108.177.98.102|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e=download&nonce=e8380gssvghts&user=12652593867932649914Z&hash=19tt54r3t0tkpv7q1i14eav3i2sfs3pn [following]
# --2021-01-16 23:57:36--  https://doc-0s-64-docs.googleusercontent.com/docs/securesc/2ldv983lf3a6font6ubrsanmus0jetgk/ic4546dda04kplb75sjn1tkrsqhl2j61/1610841450000/17600740636788319470/12652593867932649914Z/1dyYmTItAEWIf3SRjgEMVb5kdFl2EVhBP?e=download&nonce=e8380gssvghts&user=12652593867932649914Z&hash=19tt54r3t0tkpv7q1i14eav3i2sfs3pn
# Connecting to doc-0s-64-docs.googleusercontent.com (doc-0s-64-docs.googleusercontent.com)|74.125.195.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2923 (2.9K) [text/x-pascal]
# Saving to: ‘phy_cxregression_3frec.p’
#
# phy_cxregression_3f 100%[===================>]   2.85K  --.-KB/s    in 0s
#
# 2021-01-16 23:57:36 (143 MB/s) - ‘phy_cxregression_3frec.p’ saved [2923/2923]
#
# CKA_keras.py   MIfunctions.py		 physionet.zip
# datospipeline  phy_cxregression_3frec.p  __pycache__
# drive	       physionet		 sample_data

# %%
load = pickle.load( open( "/content/drive/MyDrive/CX_Regression/codigos/giga/target_giga/results_acc_2seg_5time_2frec_3.p", "rb" )  )

# %%
load.keys()
# Out:
# dict_keys(['steps', 'f_frec', 'vtw', 'best_param', 'cv_results', 'max_acc'])

# %%
load['cv_results']['mean_test_acc']
# Out:
# array([0.9425, 0.9675, 0.945 ])

# %%
int(indx[0][1::])
# Out:
# 91

# %%
indx2=[int(indx[i][1::]) for i in range(len(indx))]
indx2
# Out:
# [91,
#  98,
#  59,
#  1,
#  38,
#  81,
#  7,
#  18,
#  54,
#  12,
#  41,
#  60,
#  3,
#  39,
#  109,
#  72,
#  89,
#  43,
#  78,
#  21,
#  97,
#  55,
#  94,
#  77,
#  24,
#  25,
#  90,
#  56,
#  74,
#  14,
#  15,
#  69,
#  37,
#  40,
#  84,
#  20,
#  79,
#  105,
#  101,
#  10,
#  17,
#  67,
#  104,
#  46,
#  71,
#  63,
#  28,
#  102,
#  13,
#  66,
#  49,
#  73,
#  68,
#  2,
#  4,
#  53,
#  76,
#  96,
#  32,
#  108,
#  11,
#  93,
#  35,
#  5,
#  23,
#  80,
#  47,
#  95,
#  51,
#  27,
#  6,
#  33,
#  45,
#  52,
#  61,
#  48,
#  64,
#  57,
#  65,
#  86,
#  50,
#  42,
#  103,
#  44,
#  30,
#  16,
#  75,
#  36,
#  26,
#  31,
#  70,
#  58,
#  8,
#  107,
#  87,
#  99,
#  106,
#  62,
#  19,
#  22,
#  34,
#  83,
#  85,
#  29,
#  82,
#  9]

# %%
=plt.plot(np.flip(np.sort(acc_subj))*100)
plt.plot(results['y_origi'])

# %%
np.sort(np.asarray(acc_subj))
# Out:
# array([0.41111111, 0.42222222, 0.43333333, 0.43333333, 0.44444444,
#        0.44444444, 0.45555556, 0.46666667, 0.46666667, 0.46666667,
#        0.47777778, 0.47777778, 0.47777778, 0.47777778, 0.47777778,
#        0.48888889, 0.48888889, 0.48888889, 0.48888889, 0.48888889,
#        0.48888889, 0.5       , 0.5       , 0.5       , 0.5       ,
#        0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#        0.51111111, 0.51111111, 0.51111111, 0.51111111, 0.51111111,
#        0.51111111, 0.51111111, 0.51111111, 0.51111111, 0.52222222,
#        0.52222222, 0.52222222, 0.52222222, 0.52222222, 0.52222222,
#        0.52222222, 0.52222222, 0.53333333, 0.54444444, 0.54444444,
#        0.54444444, 0.54444444, 0.54444444, 0.54444444, 0.54444444,
#        0.54444444, 0.55555556, 0.55555556, 0.55555556, 0.56666667,
#        0.56666667, 0.56666667, 0.57777778, 0.57777778, 0.57777778,
#        0.57777778, 0.57777778, 0.57777778, 0.57777778, 0.57777778,
#        0.57777778, 0.57777778, 0.57777778, 0.58888889, 0.58888889,
#        0.58888889, 0.58888889, 0.6       , 0.6       , 0.6       ,
#        0.6       , 0.6       , 0.61111111, 0.61111111, 0.61111111,
#        0.61111111, 0.61111111, 0.62222222, 0.62222222, 0.63333333,
#        0.6375    , 0.64444444, 0.66666667, 0.66666667, 0.68888889,
#        0.68888889, 0.71111111, 0.72222222, 0.74444444, 0.75555556,
#        0.75555556, 0.78888889, 0.8       , 0.83333333, 0.87777778,
#        0.97777778])

# %%
IN=np.asarray(indx)
np.flip(IN[np.argsort(np.asarray(acc_subj))])
# Out:
# array(['S029', 'S007', 'S094', 'S054', 'S042', 'S072', 'S056', 'S062',
#        'S048', 'S015', 'S031', 'S070', 'S040', 'S032', 'S034', 'S104',
#        'S085', 'S035', 'S068', 'S073', 'S063', 'S012', 'S019', 'S108',
#        'S002', 'S093', 'S074', 'S049', 'S018', 'S045', 'S091', 'S022',
#        'S008', 'S069', 'S077', 'S053', 'S050', 'S021', 'S011', 'S071',
#        'S055', 'S017', 'S080', 'S060', 'S095', 'S009', 'S043', 'S025',
#        'S010', 'S066', 'S037', 'S097', 'S083', 'S109', 'S102', 'S075',
#        'S081', 'S003', 'S082', 'S041', 'S099', 'S076', 'S023', 'S089',
#        'S052', 'S044', 'S105', 'S014', 'S086', 'S004', 'S107', 'S006',
#        'S106', 'S046', 'S013', 'S096', 'S001', 'S033', 'S027', 'S047',
#        'S039', 'S078', 'S067', 'S061', 'S036', 'S058', 'S026', 'S103',
#        'S090', 'S087', 'S038', 'S084', 'S098', 'S065', 'S057', 'S005',
#        'S059', 'S020', 'S101', 'S024', 'S079', 'S051', 'S016', 'S030',
#        'S028', 'S064'], dtype='<U4')

# %%
mean_std= ['mean_test_acc' , 'std_test_acc']
mean_std[]
# Out:
# ['mean_test_acc', 'std_test_acc']

# %%
import time
for i in range(len(listdir)):
    if listdir[i] == 'S096':
        print('Pos '+str(i)+' Sub '+str(listdir[i]))
        taget_phy['indx'][i]
# Out:
# Pos 57 Sub S096

# %% [markdown]
# Topoplots

# %%
tau =  4
overlap=1-0.5
ti = 4
tf = 40
tti = np.arange(ti,tf-tau+(tau*overlap),tau*overlap)
ttf = np.arange(ti+tau,tf+tau*overlap,tau*overlap)
f_frec = np.array([tti,ttf]).T

tau =  2
step = 0.5
ti = 2
tf = 6
tti = np.arange(ti,tf-tau+(step),step)
ttf = np.arange(ti+tau,tf+step,step)
vtw = np.array([tti,ttf]).T

j = 51
sbj = listdir[j]
XX = loadmat('../input/gcpds-physionet/'+sbj+'/eeg/raw.mat')
data=XX['X']
data[0][0].shape
Xraw = np.array([data[0][j] for j in range(len(data[0]))])
fs = XX['fs'][0][0]
ch = XX['channels'][0]
channels_names = [ch[c][0] for c in range(len(ch))]
yy = XX['y']
y = np.array([yy[j][0] for j in range(len(yy))])-1
# montage = mne.channels.read_montage(db.metadata['montage'], channels_names)
# info = mne.create_info(channels_names, sfreq=fs, ch_types="eeg",montage=montage)

# %%
import mne
import numpy as np
from typing import List

def get_epochs(data: np.ndarray, classes: np.ndarray,  labels:List[str], 
               tmin:int, montage_name:str, sampling_rate:int, 
               channels_names:List[str], **kwargs) -> mne.EpochsArray:
    """
    Creates a `mne.Epochs` with their respective montage information from raw data.
    
    Parameters
    ----------
    
    data
        Numpy array with the shape (trials, channels, time).
    classes
        Numpy array with the labels as integers.
    labels
        The label descriptor for each class.
    tmin
        Time in seconds before the event, is used to center the event in t=0,
        is negative.
    montage_name
        One of the montages defined in `mne.channels.get_builtin_montages()`.
    sampling_rate
        Sample frecuency.
    channels_names
        List of channels names, no matter the capitalization.

    Returns
    -------
    epochs
        The `mne.EpochsArray` object.
    """

    montage = mne.channels.make_standard_montage(montage_name)

    # Channels names with the MNE standard capitalization 
    source = channels_names
    target = montage.ch_names
    channels_names = []
    for ch_s in source:
        for ch_t in target:
            if ch_s.lower().strip() == ch_t.lower().strip():
                channels_names.append(ch_t)

    # Missing channels
    channels_missings = set(channels_names).difference(set(montage.ch_names))
    if channels_missings:
        print(f"Missing {channels_missings} channels in {montage_name} montage.\n"
              f"Missing channels will be removed from MNE Epochs")

    # Info
    info = mne.create_info(list(channels_names), sfreq=sampling_rate, ch_types="eeg")
    info.set_montage(montage_name)

    # Events
    events = [[i, 1, cls] for i, cls in enumerate(classes)]
    event_id = {e: i for i, e in enumerate(labels)}

    return mne.EpochsArray(data, info, events=events, tmin=tmin, event_id=event_id, **kwargs)

# %%
epochs = get_epochs(data=Xraw, classes=y, labels=['right hand', 'left hand'], tmin=-2, montage_name='standard_1005', sampling_rate=fs, channels_names=channels_names)

# %%
montage = epochs.get_montage()
montage.plot(kind='topomap', show_names=True)

evoked = epochs['izq'].average()

fig = plt.figure(figsize=(10, 5), dpi=90)
ax = plt.subplot(111)
evoked.plot(axes=ax, spatial_colors=True);

# %%
times = np.linspace(0, 4, 6)

epochs['a'].average().plot_topomap(times,)
