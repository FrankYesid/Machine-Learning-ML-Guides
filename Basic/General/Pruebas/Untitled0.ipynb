# %%
import os
dir_path = '/content/drive/MyDrive/ETB/Codes/2022/Functions/Normalization/'
os.chdir(dir_path)
from func_normalization_lowi import *
# df_data = main(df)
