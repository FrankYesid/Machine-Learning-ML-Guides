# %%
# !pip install wand
# !apt-get install python-wand
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.6/143.6 kB 3.5 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package python-wand is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
#
# E: Package 'python-wand' has no installation candidate

# %%
# !pip install pyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyocr: filename=pyocr-0.8.3-py3-none-any.whl size=37344 sha256=72261f2328ca24f216588abf385139b9fb5b8f518344d140e50f4b0d99722779
#   Stored in directory: /root/.cache/pip/wheels/f9/58/c3/0dd3a4332eff16665240a182bfb77e15a3254196f9476ea508
# Successfully built pyocr
# ...

# %%
# !apt-get install libmagickwand-dev

# %%
# !pip install ghostscript

# %%
# Import the required libraries
from wand.image import Image
from PIL import Image as PI
import pyocr
import pyocr.builders
import io, sys

# %%
import os

# %%
# !ls
# Out:
# ReportePDA_FrankYesidZapataCastaño.pdf	sample_data

# %%
#  Find all documents with .pdf extension in current directory
pdf_files = []

dir_path = os.getcwd()
for file in os.listdir(dir_path):
	if file.endswith(".pdf"):
		pdf_files.append(file)

# %%
pdf_files
# Out:
# ['ReportePDA_FrankYesidZapataCastaño.pdf']

# %%
# Get the handle of the OCR library (in this case, tesseract)
tools = pyocr.get_available_tools()
if len(tools) == 0:
	print("No OCR tool found!")
	sys.exit(1)
tool = tools[0]
print("Will use tool '%s'" % (tool.get_name()))
# Out:
# Will use tool 'Tesseract (C-API)'

# %%
tool.get_available_languages
# Out:
# <function pyocr.libtesseract.get_available_languages()>

# %%
# @title Instalar idioma español para el traductor
# !apt-get install tesseract-ocr-spa
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd tesseract-ocr-spa
# 0 upgraded, 4 newly installed, 0 to remove and 13 not upgraded.
# Need to get 5,802 kB of archives.
# After this operation, 18.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1 [1,598 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr amd64 4.1.1-2build2 [262 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-spa all 1:4.00~git30-7274cfa-1 [951 kB]
# Fetched 5,802 kB in 1s (5,095 kB/s)
# ...

# %%
# Get the language
langs = tool.get_available_languages()
print("Available languages: %s" % ", ".join(langs))
lang = langs[2] # For 0: English 2: Spanish
print("Will use language '%s'" % (lang))
# Out:
# Available languages: eng, osd, spa
# Will use language 'spa'

# %%
pdf_files
# Out:
# ['ReportePDA_FrankYesidZapataCastaño.pdf']

# %%
# Setup two lists which will be used to hold our images and final_text
req_image = []
final_text = []

# Open the PDF file using wand and convert it to jpeg
image_pdf = Image(filename="ReportePDA_FrankYesidZapataCastaño.pdf", resolution=300)
image_jpeg = image_pdf.convert('pdf')

# %%
Image(filename=file,resolution=300)

# %%
from wand.image import Image

file='/content/ReportePDA_FrankYesidZapataCastaño.pdf'
with(Image(filename=file,resolution=300)) as img:

  images=img.sequence
  pages=len(images)

  for i in range(pages):
      images[i].type='grayscale'
      Image(images[i]).save(filename=str(i+1)+'.png')

# %%
# !pip install pytesseract

# %%
# !pip install pillow

# %%
# !apt-get install imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   imagemagick-6.q16 libnetpbm10 netpbm
# Suggested packages:
#   imagemagick-doc autotrace cups-bsd | lpr | lprng enscript gimp gnuplot grads
#   hp2xx html2ps libwmf-bin mplayer povray radiance sane-utils texlive-base-bin
#   transfig ufraw-batch
# The following NEW packages will be installed:
#   imagemagick imagemagick-6.q16 libnetpbm10 netpbm
# 0 upgraded, 4 newly installed, 0 to remove and 13 not upgraded.
# Need to get 1,517 kB of archives.
# After this operation, 5,324 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 imagemagick-6.q16 amd64 8:6.9.10.23+dfsg-2.1ubuntu11.9 [427 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 imagemagick amd64 8:6.9.10.23+dfsg-2.1ubuntu11.9 [14.4 kB]
# ...

# %%
# !pip install wand

# %%
import io
from PIL import Image
import pytesseract
from wand.image import Image as wi

# %%
pdf = wi(filename = "/content/sample2.pdf", resolution = 300)
pdfImage = pdf.convert('jpeg')
# Out:
# ---------------------------------------------------------------------------
# PolicyError                               Traceback (most recent call last)
# <ipython-input-53-8c89514b8d2e> in <cell line: 1>()
# ----> 1 pdf = wi(filename = "/content/sample2.pdf", resolution = 300)
#       2 pdfImage = pdf.convert('jpeg')
#
# /usr/local/lib/python3.10/dist-packages/wand/image.py in __init__(self, image, blob, file, filename, pseudo, background, colorspace, depth, extract, format, height, interlace, resolution, sampling_factors, units, width)
#    9363                     self.read(blob=blob)
#    9364                 elif filename is not None:
# -> 9365                     self.read(filename=filename)
#    9366                 # clear the wand format, otherwise any subsequent call to
#    9367                 # MagickGetImageBlob will silently change the image to this
#
# ...

# %%
# !pip install --upgrade PyPDF2==2.12.1
# !pip install textract
# !pip install pdf2image
# !pip install pytesseract
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 14.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 60.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 65.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 76.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 12.6 MB/s eta 0:00:00
# ...

# %%
from PyPDF2 import PdfFileWriter, PdfFileReader

# %%
inputpdf = PdfFileReader(open("/content/sample2.pdf", "rb"))

# %%
inputpdf = PdfFileReader(open("/content/ReportePDA_FrankYesidZapataCastaño.pdf", "rb"))

# %%
inputpdf.numPages
# Out:
# 2

# %%
for i in range(inputpdf.numPages):
    output = PdfFileWriter()
    output.addPage(inputpdf.getPage(i))
    with open("document-page%s.pdf" % i, "wb") as outputStream:
        output.write(outputStream)

# %%
inputpdf.getPage(1).extractText()
# Out:
# '3 Python commands 9\n3.1 Comments . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 9\n3.2 Numbers and other data types . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 9\n3.2.1 The typefunction . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 9\n3.2.2 Strings . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 10\n3.2.3 Lists and tuples . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 10\n3.2.4 The range function . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 11\n3.2.5 Boolean values . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 11\n3.3 Expressions . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 11\n3.4 Operators . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 11\n3.5 Variables and assignment . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 13\n3.6 Decisions . 
# ...
