# %% [markdown]
# # Organizar cuaderno con la información de clasificar por variables categóricas, nominales y ordinales

# %%
#@title Libreria

# %%
#@title Cargar los datos

# %%
#@title organizar la información relevante

# %%
#@title modelos utilizados en el estado del arte

# %%
#@title Ejemplo de usar la base de datos.
